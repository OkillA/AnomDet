# %%
import cv2 as cv
import matplotlib.pyplot as plt
#load image
image = cv.imread("7.jpg")

#convert to grayscale image
gray_scale = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

#initialize SIFT object
sift = cv.SIFT_create()

#detect keypoints
keypoints, _= sift.detectAndCompute(image, None)

#draw keypoints
sift_image = cv.drawKeypoints(gray_scale, keypoints, None)

plt.imshow(sift_image)

# %%
import cv2 as cv
import matplotlib.pyplot as plt

#load image
image = cv.imread("cascade.jpg")

#convert to grayscale image
gray_scale = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

#initialize SIFT object
sift = cv.SIFT_create()

#detect keypoints
keypoints, descriptors= sift.detectAndCompute(image, None)

#draw keypoints
sift_image = cv.drawKeypoints(gray_scale, keypoints, None)
#print(keypoints)
print(descriptors)
print(descriptors.shape)
print(descriptors[1])
plt.imshow(sift_image)
# Out:
# [ WARN:0@3437.649] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('cascade.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [6], in <module>
#       5 image = cv.imread("cascade.jpg")
#       7 #convert to grayscale image
# ----> 8 gray_scale = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
#      10 #initialize SIFT object
#      11 sift = cv.SIFT_create()
#
# error: OpenCV(4.5.5) /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2 
import matplotlib.pyplot as plt
from mahotas.features import surf

#load image
image = cv2.imread("test.jpg")

#convert to grayscale image
gray_scale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

#initialize SIFT object
# surf = cv2.SURF()
# sift = cv.SIFT_create()

surf = cv2.xfeatures2d.SURF_create()
# surf = cv.xfeatures2d.SURF_create()


#detect keypoints
keypoints, descriptors= surf.detectAndCompute(image, None)

#draw keypoints
sift_image = cv.drawKeypoints(gray_scale, keypoints, None)
#print(keypoints)
# print(descriptors)
# print(descriptors.shape)
# print(descriptors[1])
plt.imshow(sift_image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <module>
#       9 gray_scale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#      11 #initialize SIFT object
#      12 # surf = cv2.SURF()
#      13 # sift = cv.SIFT_create()
# ---> 15 surf = cv2.xfeatures2d.SURF_create()
#      16 # surf = cv.xfeatures2d.SURF_create()
#      17
#      18
#      19 #detect keypoints
#      20 keypoints, descriptors= surf.detectAndCompute(image, None)
#
# AttributeError: module 'cv2' has no attribute 'xfeatures2d'

# %%
pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in /Users/arun/miniforge3/lib/python3.9/site-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.19.3 in /Users/arun/miniforge3/lib/python3.9/site-packages (from opencv-contrib-python) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/arun/miniforge3/lib/python3.9/site-packages (4.5.5.64)
# Requirement already satisfied: numpy>=1.14.5 in /Users/arun/miniforge3/lib/python3.9/site-packages (from opencv-python) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.
