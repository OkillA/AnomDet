# %% [markdown]
# #Importing Libraries

# %%
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt

# %% [markdown]
# #Reading the image

# %%
img = imread('7.jpg')
plt.axis("off")
plt.imshow(img)
print(img.shape)
# Out:
# (450, 450, 3)

# %% [markdown]
# #Resizing image

# %%
resized_img = resize(img, (56*4, 56*4))
plt.axis("off")
plt.imshow(resized_img)
print(resized_img.shape)
# Out:
# (224, 224, 3)

# %%
resized_img = resize(img, (128*4, 64*4))
plt.axis("off")
plt.imshow(resized_img)
print(resized_img.shape)
# Out:
# (512, 256, 3)

# %% [markdown]
# #Creating and visualizing HOG Features

# %%
fd, hog_image = hog(resized_img, orientations=4, pixels_per_cell=(14,14),
                	cells_per_block=(1,1), visualize=True, multichannel=True)
plt.axis("off")
plt.imshow(hog_image, cmap="gray")
plt.show()

# %%
len(fd)
# Out:
# 1024

# %%
print(fd)
# Out:
# [0.34358934 0.35904431 0.68211627 ... 0.5        0.5        0.5       ]
